# %%
import torchvision
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
'''
mnist_trainset = torchvision.datasets.MNIST(root='./MNIST_TRAIN', train=True, download=False, transform=None)
mnist_testset = torchvision.datasets.MNIST(root='./MNIST_TEST', train=False, download=False, transform=None)
svhn_trainset = torchvision.datasets.SVHN('./train_32x32.mat', split='train', transform=None, target_transform=None, download=False)
svhn_testset = torchvision.datasets.SVHN('./SVHN', split='test', transform=None, target_transform=None, download=False)
svhn_extraset = torchvision.datasets.SVHN('./SVHN', split='extra', transform=None, target_transform=None, download=False)
'''

# %% [markdown]
# ## Dataset Shape

# %%
print("MNIST TRAN SET:  ", list(mnist_trainset.train_data.shape))
print("MNIST TEST SET:  ", list(mnist_testset.test_data.shape))
print("SVHN TRAIN SET:  ", list(svhn_trainset.data.shape))
print("SVHN TEST SET:   ", list(svhn_testset.data.shape))
print("SVHN EXTRA SET:  ", list(svhn_extraset.data.shape))
# Out:
# MNIST TRAN SET:   [60000, 28, 28]
# MNIST TEST SET:   [10000, 28, 28]
# SVHN TRAIN SET:   [73257, 3, 32, 32]
# SVHN TEST SET:    [26032, 3, 32, 32]
# SVHN EXTRA SET:   [531131, 3, 32, 32]

# %% [markdown]
# ## Dataset Label Distribution

# %%
plt.hist(list(mnist_trainset.train_labels),color='r',label="TRAIN SET")
plt.hist(list(mnist_testset.test_labels),color='b',label="TEST SET")
plt.title("Plot of MNIST DATASET")
plt.xlabel("Data Labels")
plt.ylabel("Frequency")
plt.ylim([0,8000])
plt.legend()
plt.show()

# %%
plt.hist(list(svhn_trainset.labels), color='r',label="TRAIN SET")
plt.hist(list(svhn_testset.labels),color='b', label="TEST SET")
plt.xlabel("Data Labels")
plt.ylabel("Frequency")
plt.title("Plot of SVHN TRAIN AND TRAIN DATASET")
plt.legend()
plt.show()

# %%
plt.hist(list(svhn_extraset.labels))
plt.xlabel("Data Labels")
plt.ylabel("Frequency")
plt.title("Plot of SVHN EXTRA TRAIN SET")
plt.show()

# %% [markdown]
# ## MNIST SAMPLES

# %%
plt.figure(figsize=(5,6))
for i in range(30):
    plt.subplot(5,6,i+1)
    plt.imshow(mnist_trainset.train_data[i+150],cmap="gray")
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# %%
i
# Out:
# 20

# %% [markdown]
# ## SVHN SAMPLES

# %%
plt.figure(figsize=(4,5))
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(np.uint8(sum(svhn_trainset.data[i+150])/2), cmap="gray")
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()
